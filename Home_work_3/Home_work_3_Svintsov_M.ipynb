# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Task 3

# %%
a = np.zeros((15, 28))
a[2:-2,1]=1; a[2,2:6]=1
a[2:7,6]=1; a[7:-2,7]=1
a[7,2:7]=1; a[-3,2:7]=1
a[2:-2,10]=1; a[2:-2,14]=1 
a[2:-2,18]=1; a[-3,10:19]=1
a[-3,21:-1]=1; a[2,21:-1]=1;
a[7,21:-1]=1; a[2 :-2,-2]=1;
plt.imshow(a)
plt.show()
a.shape
# Out:
# (15, 28)

# %%
r = 0
for i in s:
    if not np.allclose(i, 0):
        r += 1
print('Ранг матрицы А =', r)
# Out:
# Ранг матрицы А = 5

# %%
u, s, vh = np.linalg.svd(a)
ss = np.zeros((15, 28))
for i in range(0, r):
    ss[i][i] = s[i]
    A = u @ ss @ vh
    plt.imshow(A)
    plt.title('Приближение исходной матрицы матрицей с рангом = '+ str(i+1))
    plt.show()

# %% [markdown]
# ## Task4
# В отдельном файле
